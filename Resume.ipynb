# %%
import numpy as np
import pandas as pd
import csv
import re
import spacy
import sys
#reload(sys)
import pandas as pd
#sys.setdefaultencoding('utf8')
#from cStringIO import StringIO
from io import StringIO
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
import os
import sys, getopt
import numpy as np
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
#Function converting pdf to string
def convert(fname, pages=None):
    if not pages:
        pagenums = set()
    else:
        pagenums = set(pages)

    output = StringIO()
    manager = PDFResourceManager()
    converter = TextConverter(manager, output, laparams=LAParams())
    interpreter = PDFPageInterpreter(manager, converter)

    infile = open(fname, 'rb')
    for page in PDFPage.get_pages(infile, pagenums):
        interpreter.process_page(page)
    infile.close()
    converter.close()
    text = output.getvalue()
    output.close
    return text

def phone(str1):
    if re.findall(r'\d{5}\s\d{5}',str1,re.IGNORECASE):
        return re.findall(r'\d{5}\s\d{5}',str1,re.IGNORECASE)
    elif re.findall(r'\d{5}-\d{5}',str1,re.IGNORECASE):
        return re.findall(r'\d{5}-\d{5}',str1,re.IGNORECASE)
    elif re.findall(r'\d{3}\s\d{3}\s\d{4}',str1,re.IGNORECASE):
        return re.findall(r'\d{3}\s\d{3}\s\d{4}',str1,re.IGNORECASE)
    elif re.findall(r'\d{3}-\d{3}-\d{4}',str1,re.IGNORECASE):
        return re.findall(r'\d{3}-\d{3}-\d{4}',str1,re.IGNORECASE)
    elif re.findall(r'\d{12}',str1,re.IGNORECASE):
        return re.findall(r'\d{12}',str1,re.IGNORECASE) 
    elif re.findall(r'\d{10}',str1,re.IGNORECASE):
        return re.findall(r'\d{10}',str1,re.IGNORECASE) 
    elif re.findall(r'\d\d\s\d{10}',str1,re.IGNORECASE):
        return re.findall(r'\d\d\s\d{10}',str1,re.IGNORECASE)
    
def extract_email_addresses(string):
    r = re.compile(r'[\w\.-]+@[\w\.-]+')
    return r.findall(string)


filename='C:/Users/Ashok/Downloads/Debdattas_Resume.pdf'

resume_string = convert(filename)
str1= resume_string.replace(' ', ' ').replace('\t', ' ').replace('\n', ' ')

import os
base=os.path.basename(filename)    
name=base.split('_')[0]

phone=phone(str1)

email=extract_email_addresses(str1)

l1=['PCA',
 'dimension reduction',
 'machine',
 'Python',
 'PCA',
 'Logistic Regression',
 'Decision Tree',
 'Random Forest',
 'Naïve Baye',
 'Regression testing',
 'analysis /  reporting',
 'sql',
 'statistics',
 'EDA',
 'Tableau',
 'Data cleaning',
 'Data Visualization   Data analysis',
 'Statistical modeling',
 'Machine learning',
 'Supervised learning',
'Econometrics and Time Series Analysis', 
    'Design of Experiments', 'Linear Models', 'Large Sample Theory',
'Stochastic Process', 'Non-Parametric Methods',
'Descision Theory', 'Data Mining', 'Statistical Inference', 
    'Probability Theory', 'Multivariate Statistical Modelling', 'Biostatistics',
'Business Statistics','Machine Learning','Computer Vision',
    'MS Excel', 'Power Point', 'Power BI','R','SAS','SQL','Excel','Machine Learning','Data Science']

l = [item.lower() for item in l1]

str2=str1.lower()
skills=set(re.findall(r"(?=("+'|'.join(l)+r"))",str2))

mydict=dict()
mydict['skills']=skills
Data=pd.DataFrame({'Name':name,'Phone':phone,'E-mail':email,'Skills':mydict.values()})

l2=['b.com','b.tech','b.sc','BE','B.Sc','B.Tech','Honours in Statistics','B.COM','B.E.']
l3=['Masters in Statistics and Computing','m.tech','m.sc','M.Sc']

Bachelors=set(re.findall(r"(?=("+'|'.join(l2)+r"))",str1))
if (len(Bachelors)!=0):
    Data['Bachelors']=list(Bachelors)[0]
else:
    Data['Bachelors']=0
    
Masters=set(re.findall(r"(?=("+'|'.join(l3)+r"))",str1))
if (len(Masters)!=0):
    Data['Masters']=list(Masters)[0]
else:
    Data['Masters']=0
    

headers=['summary','synopsis','academics','education','skills','skills summary','professional summary','academic projects','projects','experience','responsibilities','certifications']
header_upper = [item.upper() for item in headers]
header_title = [item.title() for item in headers]
#print(header_upper)
header_Proj_upper=list(re.findall(r"(?=("+'|'.join(header_upper)+r"))",str1))
header_Proj_title=list(re.findall(r"(?=("+'|'.join(header_title)+r"))",str1))
FInal_headers=[]
if len(header_Proj_title)>len(header_Proj_upper):
    Final_headers=header_Proj_title
else:
    Final_headers=header_Proj_upper
#print(list(set(Final_headers)))


a,b=str1.find('PROJECT'),str1.find('\n')
a1=str1[a:b]
c,d=str1.find('EXPERIENCE'),str1.find('\n')
a2=str1[c:d]
e,f=str1.find('Project'),str1.find('\n')
a3=str1[e:f]
g,h=str1.find('Experience'),str1.find('\n')
a4=str1[g:h]

m1=len(a1)
m2=len(a2)
m3=len(a3)
m4=len(a4)


if ((m1>m2) & (m1>m3) & (m1>m4)):
    Data['Projects']=a1
elif ((m2>m1) & (m2>m3) & (m2>m4)):
    Data['Projects']=a2
elif ((m3>m1) & (m3>m2) & (m3>m4)):
    Data['Projects']=a3
else:
    Data['Projects']=a4
    
Data
# Out:
#         Name       Phone                  E-mail  \
# 0  Debdattas  8697828012  dishadelhi16@gmail.com
#
#                                               Skills              Bachelors  \
# 0  ({r, python, data science, computer vision, ec...  Honours in Statistics
#
#                                Masters  \
# 0  Masters in Statistics and Computing
#
#                                             Projects
# 0  EXPERIENCE Data Science Intern PerkFinance 07/...

# %%
Data.to_excel('C:/Users/Ashok/Downloads/demo.xlsx')

# %%
one= [i for i in Final_headers if re.search(r'PROJECT', i) ]
print(len(one))
#x1,y1=str1.find(one),str1.find('\n')
#z1=str1[x1:y1]

two= [i for i in Final_headers if re.search(r'Project', i) ]
print(len(two))
#x2,y2=str1.find(two),str1.find('\n')
#z2=str1[x2:y2]

three= [i for i in Final_headers if re.search(r'EXPERIENCE', i) ]
print(len(three))
#x3,y3=str1.find(three),str1.find('\n')
#z3=str1[x3:y3]

four= [i for i in Final_headers if re.search(r'Experience', i) ]
print(len(four))
#x4,y4=str1.find(four),str1.find('\n')
#z4=str1[x4:y4]
# Out:
# 2
# 0
# 1
# 0

# %%
path='C:/Users/Ashok/Downloads/Simranjeet Singh CV.docx'

# %%
import docx2txt
MY_TEXT = docx2txt.process(path)
str1=MY_TEXT
str1= str1.replace(' ', ' ').replace('\t', ' ').replace('\n', ' ')


def phone(str1):
    if re.findall(r'\d{5}\s\d{5}',str1,re.IGNORECASE):
        return re.findall(r'\d{5}\s\d{5}',str1,re.IGNORECASE)
    elif re.findall(r'\d{5}-\d{5}',str1,re.IGNORECASE):
        return re.findall(r'\d{5}-\d{5}',str1,re.IGNORECASE)
    elif re.findall(r'\d{3}\s\d{3}\s\d{4}',str1,re.IGNORECASE):
        return re.findall(r'\d{3}\s\d{3}\s\d{4}',str1,re.IGNORECASE)
    elif re.findall(r'\d{3}-\d{3}-\d{4}',str1,re.IGNORECASE):
        return re.findall(r'\d{3}-\d{3}-\d{4}',str1,re.IGNORECASE)
    elif re.findall(r'\d{12}',str1,re.IGNORECASE):
        return re.findall(r'\d{12}',str1,re.IGNORECASE) 
    elif re.findall(r'\d{10}',str1,re.IGNORECASE):
        return re.findall(r'\d{10}',str1,re.IGNORECASE) 
    elif re.findall(r'\d\d\s\d{10}',str1,re.IGNORECASE):
        return re.findall(r'\d\d\s\d{10}',str1,re.IGNORECASE)
    
def extract_email_addresses(string):
    r = re.compile(r'[\w\.-]+@[\w\.-]+')
    return r.findall(string)

import os
base=os.path.basename(filename)    
name=base.split('_')[0]

phone=phone(str1)

email=extract_email_addresses(str1)

l1=['PCA',
 'dimension reduction',
 'machine',
 'Python',
 'PCA',
 'Logistic Regression',
 'Decision Tree',
 'Random Forest',
 'Naïve Baye',
 'Regression testing',
 'analysis /  reporting',
 'sql',
 'statistics',
 'EDA',
 'Tableau',
 'Data cleaning',
 'Data Visualization   Data analysis',
 'Statistical modeling',
 'Machine learning',
 'Supervised learning',
'Econometrics and Time Series Analysis', 
    'Design of Experiments', 'Linear Models', 'Large Sample Theory',
'Stochastic Process', 'Non-Parametric Methods',
'Descision Theory', 'Data Mining', 'Statistical Inference', 
    'Probability Theory', 'Multivariate Statistical Modelling', 'Biostatistics',
'Business Statistics','Machine Learning','Computer Vision',
    'MS Excel', 'Power Point', 'Power BI','R','SAS','SQL','Excel','Machine Learning','Data Science']

l = [item.lower() for item in l1]

str2=str1.lower()
skills=set(re.findall(r"(?=("+'|'.join(l)+r"))",str2))

mydict=dict()
mydict['skills']=skills
Data=pd.DataFrame({'Name':name,'Phone':phone,'E-mail':email,'Skills':mydict.values()})

l2=['b.com','b.tech','b.sc','BE','B.Sc','B.Tech','Honours in Statistics','B.COM','B.E.']
l3=['Masters in Statistics and Computing','m.tech','m.sc','M.Sc']

Bachelors=set(re.findall(r"(?=("+'|'.join(l2)+r"))",str1))
if (len(Bachelors)!=0):
    Data['Bachelors']=list(Bachelors)[0]
else:
    Data['Bachelors']=0
    
Masters=set(re.findall(r"(?=("+'|'.join(l3)+r"))",str1))
if (len(Masters)!=0):
    Data['Masters']=list(Masters)[0]
else:
    Data['Masters']=0
    

headers=['summary','synopsis','academics','education','skills','skills summary','professional summary','academic projects','projects','experience','responsibilities','certifications']
header_upper = [item.upper() for item in headers]
header_title = [item.title() for item in headers]
#print(header_upper)
header_Proj_upper=list(re.findall(r"(?=("+'|'.join(header_upper)+r"))",str1))
header_Proj_title=list(re.findall(r"(?=("+'|'.join(header_title)+r"))",str1))
FInal_headers=[]
if len(header_Proj_title)>len(header_Proj_upper):
    Final_headers=header_Proj_title
else:
    Final_headers=header_Proj_upper
#print(list(set(Final_headers)))


a,b=str1.find('PROJECT'),str1.find('\n')
a1=str1[a:b]
c,d=str1.find('EXPERIENCE'),str1.find('\n')
a2=str1[c:d]
e,f=str1.find('Project'),str1.find('\n')
a3=str1[e:f]
g,h=str1.find('Experience'),str1.find('\n')
a4=str1[g:h]

m1=len(a1)
m2=len(a2)
m3=len(a3)
m4=len(a4)


if ((m1>m2) & (m1>m3) & (m1>m4)):
    Data['Projects']=a1
elif ((m2>m1) & (m2>m3) & (m2>m4)):
    Data['Projects']=a2
elif ((m3>m1) & (m3>m2) & (m3>m4)):
    Data['Projects']=a3
else:
    Data['Projects']=a4
    
Data
# Out:
#         Name       Phone                          E-mail  \
# 0  Debdattas  9899596381  simranjeetsingh19980@gmail.com
#
#                                               Skills Bachelors  Masters  \
# 0  ({power bi, r, data cleaning, sql, power point...      BSE         0
#
#                                             Projects
# 0  Experience  Data Analyst   Nurture tECH Academ...

# %%
import cv2
import pytesseract
pytesseract.pytesseract.tesseract_cmd=r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
img=cv2.imread('C:/laptop/backup/Backup/Tax/883568_BGC.jpg')
text=pytesseract.image_to_string(img)
print(text)
# Out:
# TATA
# Declaration and General Consent to Background Investigation
#
# To be signed by Associate / Business Associate
#
# In connection with rendering services to Tata Consultancy Services Ltd. (the "Company"), as an Associate /
# Business Associate (BA)
#
# I hereby agree as follows:
#
# | certify that the information furnished in this form as well as in all other forms filled-in by me in conjunction
# with my rendering of services as an Associate / BA is factually correct and subject to verification by TCS
# including Reference Check and Background Verification.
#
# | accept that my services as Associate / BA can be revoked and/ or terminated without any notice at any time
# in future if any information has been found to be false, misleading, deliberately omitted/ suppressed.
#
# ‘As a condition of Company's consideration of my rendering of services as an Associate / BA to the
# ‘Company, | hereby give my consent to the Company to investigate or cause to be investigated through any
# third parties my personal, educational and pre or post-employment history, criminal history and any other
# checks, including Drug test as required for complying with TCS and or Client specific BGC requirements. |
# Understand that the background investigation will include, but not be limited to, verification of all information
# given by me to the Company. | confirm that the Company is entitled to share such investigation report with
# its clients to the extent necessary in connection with the Services, which | may be required to provide to such
# lients. | confirm and undertake that the Company shall incur no liability or obligation of any nature
# ‘whatsoever resulting from such investigation or sharing of the investigation results as above.
#
#
#
# | certify that | am at present in sound mental and physical condition to undertake my rendering of services as
# an Associate / BA with TCS. | also declare that there is no criminal case filed against me or pending against
# ‘me in any Court of law in India or abroad and no restrictions are placed on my travelling anywhere in India or
# abroad for the purpose of business of the company.
#
#
#
# | Agree: Yes
#
# Name ASHoK TCS Employee /BAID__ 293567
# Father's Name SoBRAMAN SAM DOB__aa}oifa9
#
# Present Address Hn a lace h
# City___"RAnmALoRE State KARNATAKA Pincode 5 £n00%
# Contact No. (cell) TIISZOV335
#
# Place QRANGALOAE Date os |
#
# Proof of doc to be attached: PAN Card copy
#
#
#
# ‘TCS Confidential
# Background Check Form — Project Specific - Drug Test / IDB / Identity Check — Version 1.0 Page 1 of 1
