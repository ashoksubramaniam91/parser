# %%
import gensim 
import logging

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import pandas as pd
df = pd.read_excel('Downloads\\cif_input_list.xlsx')
df.head()
# Out:
#    S.no.     ID_No  SKU TYPE  SKU Category Brand_Final  \
# 0      1  CIF10000       NaN           NaN         YSL
# 1      2  CIF10005       NaN           NaN      Chloe
# 2      3  CIF10008       NaN           NaN      Chloe
# 3      4  CIF10009       NaN           NaN      Chloe
# 4      5  CIF10016       NaN           NaN      Chloe
#
#                                       Product Name *          Color*  \
# 0  KATE SMALL IN GRAIN DE POUDRE EMBOSSED LEATHER...     OPTIC WHITE
# 1                                   MINI CHLOÉ C BAG  autumnal brown
# 2                     SMALL CHLOÉ C DOUBLE CARRY BAG  autumnal brown
# 3                     SMALL CHLOÉ C DOUBLE CARRY BAG     cement pink
# 4                                   MEDIUM VICK TOTE            Gray
#
#                            Material* Size (for bags only)* MPN (UPC)*  \
# 0                   CALFSKIN LEATHER               Medium         NaN
# 1                          CALFSKIN                    Mni        NaN
# ...

# %%
 gensim.utils.simple_preprocess(df[['Product Name *']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ff3a03928157> in <module>()
# ----> 1 gensim.utils.simple_preprocess(df[['Product Name *']])
#
# C:\Anaconda3\lib\site-packages\gensim\utils.py in simple_preprocess(doc, deacc, min_len, max_len)
#     303     """
#     304     tokens = [
# --> 305         token for token in tokenize(doc, lower=True, deacc=deacc, errors='ignore')
#     306         if min_len <= len(token) <= max_len and not token.startswith('_')
#     307     ]
#
# C:\Anaconda3\lib\site-packages\gensim\utils.py in tokenize(text, lowercase, deacc, encoding, errors, to_lower, lower)
#     254     """
#     255     lowercase = lowercase or to_lower or lower
# --> 256     text = to_unicode(text, encoding, errors=errors)
#     257     if lowercase:
#     258         text = text.lower()
#
# ...
